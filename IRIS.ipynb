# %% [markdown]
# <a href="https://colab.research.google.com/github/adityasahani001/Deep-learning-Aditya-Sahani-2025-26/blob/main/IRIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("endofnight17j03/iris-classification")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████| 0.99k/0.99k [00:00<00:00, 495kB/s]
# Extracting files...
# Path to dataset files: C:\Users\adity\.cache\kagglehub\datasets\endofnight17j03\iris-classification\versions\1

# %%
import os

print(os.listdir(path))
# Out:
# ['IRIS.csv']

# %%
import pandas as pd

csv_path = os.path.join(path, "Iris.csv")  # adjust name if needed
df = pd.read_csv(csv_path)

df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
X = df.iloc[:, 1:-1].values   # features
y = df.iloc[:, -1].values    # species

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y = le.fit_transform(y)
